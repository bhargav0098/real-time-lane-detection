# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav0098/real-time-lane-detection/blob/main/lane7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q opencv-python

# %%
# Libraries for working with image processing
import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow
# Libraries needed to edit/save/watch video clips
from moviepy import editor
import moviepy

# %%
def frame_processor(image):
    """
    Process the input frame to detect lane lines.
    Parameters:
        image: image of a road where one wants to detect lane lines
        (we will be passing frames of video to this function)
    """
    # convert the RGB image to Gray scale
    grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # applying gaussian Blur which removes noise from the image
    # and focuses on our region of interest
    # size of gaussian kernel
    kernel_size = 5
    # Applying gaussian blur to remove noise from the frames
    blur = cv2.GaussianBlur(grayscale, (kernel_size, kernel_size), 0)
    # first threshold for the hysteresis procedure
    low_t = 50
    # second threshold for the hysteresis procedure
    high_t = 150
    # applying canny edge detection and save edges in a variable
    edges = cv2.Canny(blur, low_t, high_t)
    # since we are getting too many edges from our image, we apply
    # a mask polygon to only focus on the road
    # Will explain Region selection in detail in further steps
    region = region_selection(edges)
    # Applying hough transform to get straight lines from our image
    # and find the lane lines
    # Will explain Hough Transform in detail in further steps
    hough = hough_transform(region)
    #lastly we draw the lines on our resulting frame and return it as output
    result = draw_lane_lines(image, lane_lines(image, hough))
    return result

# %%
def region_selection(image):
    """
    Determine and cut the region of interest in the input image.
    Parameters:
        image: we pass here the output from canny where we have
        identified edges in the frame
    """
    # create an array of the same size as of the input image
    mask = np.zeros_like(image)
    # if you pass an image with more then one channel
    if len(image.shape) > 2:
        channel_count = image.shape[2]
        ignore_mask_color = (255,) * channel_count
    # our image only has one channel so it will go under "else"
    else:
          # color of the mask polygon (white)
        ignore_mask_color = 255
    # creating a polygon to focus only on the road in the picture
    # we have created this polygon in accordance to how the camera was placed
    rows, cols = image.shape[:2]
    bottom_left  = [cols * 0.1, rows * 0.95]
    top_left     = [cols * 0.4, rows * 0.6]
    bottom_right = [cols * 0.9, rows * 0.95]
    top_right    = [cols * 0.6, rows * 0.6]
    vertices = np.array([[bottom_left, top_left, top_right, bottom_right]], dtype=np.int32)
    # filling the polygon with white color and generating the final mask
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    # performing Bitwise AND on the input image and mask to get only the edges on the road
    masked_image = cv2.bitwise_and(image, mask)
    return masked_image

# %%
def hough_transform(image):
    """
    Determine and cut the region of interest in the input image.
    Parameter:
        image: grayscale image which should be an output from the edge detector
    """
    # Distance resolution of the accumulator in pixels.
    rho = 1
    # Angle resolution of the accumulator in radians.
    theta = np.pi/180
    # Only lines that are greater than threshold will be returned.
    threshold = 20
    # Line segments shorter than that are rejected.
    minLineLength = 20
    # Maximum allowed gap between points on the same line to link them
    maxLineGap = 500
    # function returns an array containing dimensions of straight lines
    # appearing in the input image
    return cv2.HoughLinesP(image, rho = rho, theta = theta, threshold = threshold,
                           minLineLength = minLineLength, maxLineGap = maxLineGap)

# %%
def average_slope_intercept(lines):
    """
    Find the slope and intercept of the left and right lanes of each image.
    Parameters:
        lines: output from Hough Transform
    """
    left_lines    = [] #(slope, intercept)
    left_weights  = [] #(length,)
    right_lines   = [] #(slope, intercept)
    right_weights = [] #(length,)

    for line in lines:
        for x1, y1, x2, y2 in line:
            if x1 == x2:
                continue
            # calculating slope of a line
            slope = (y2 - y1) / (x2 - x1)
            # calculating intercept of a line
            intercept = y1 - (slope * x1)
            # calculating length of a line
            length = np.sqrt(((y2 - y1) ** 2) + ((x2 - x1) ** 2))
            # slope of left lane is negative and for right lane slope is positive
            if slope < 0:
                left_lines.append((slope, intercept))
                left_weights.append((length))
            else:
                right_lines.append((slope, intercept))
                right_weights.append((length))
    #
    left_lane  = np.dot(left_weights,  left_lines) / np.sum(left_weights)  if len(left_weights) > 0 else None
    right_lane = np.dot(right_weights, right_lines) / np.sum(right_weights) if len(right_weights) > 0 else None
    return left_lane, right_lane

def pixel_points(y1, y2, line):
    """
    Converts the slope and intercept of each line into pixel points.
        Parameters:
            y1: y-value of the line's starting point.
            y2: y-value of the line's end point.
            line: The slope and intercept of the line.
    """
    if line is None:
        return None
    slope, intercept = line
    x1 = int((y1 - intercept)/slope)
    x2 = int((y2 - intercept)/slope)
    y1 = int(y1)
    y2 = int(y2)
    return ((x1, y1), (x2, y2))

def lane_lines(image, lines):
    """
    Create full lenght lines from pixel points.
        Parameters:
            image: The input test image.
            lines: The output lines from Hough Transform.
    """
    left_lane, right_lane = average_slope_intercept(lines)
    y1 = image.shape[0]
    y2 = y1 * 0.6
    left_line  = pixel_points(y1, y2, left_lane)
    right_line = pixel_points(y1, y2, right_lane)
    return left_line, right_line


def draw_lane_lines(image, lines, color=[255, 0, 0], thickness=12):
    """
    Draw lines onto the input image.
        Parameters:
            image: The input test image (video frame in our case).
            lines: The output lines from Hough Transform.
            color (Default = red): Line color.
            thickness (Default = 12): Line thickness.
    """
    line_image = np.zeros_like(image)
    for line in lines:
        if line is not None:
            cv2.line(line_image, *line,  color, thickness)
    return cv2.addWeighted(image, 1.0, line_image, 1.0, 0.0)

# %%
import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow
#Import everything needed to edit/save/watch video clips
from moviepy import editor
import moviepy

def region_selection(image):
    """
    Determine and cut the region of interest in the input image.
    Parameters:
        image: we pass here the output from canny where we have
        identified edges in the frame
    """
    # create an array of the same size as of the input image
    mask = np.zeros_like(image)
    # if you pass an image with more then one channel
    if len(image.shape) > 2:
        channel_count = image.shape[2]
        ignore_mask_color = (255,) * channel_count
    # our image only has one channel so it will go under "else"
    else:
          # color of the mask polygon (white)
        ignore_mask_color = 255
    # creating a polygon to focus only on the road in the picture
    # we have created this polygon in accordance to how the camera was placed
    rows, cols = image.shape[:2]
    bottom_left  = [cols * 0.1, rows * 0.95]
    top_left     = [cols * 0.4, rows * 0.6]
    bottom_right = [cols * 0.9, rows * 0.95]
    top_right    = [cols * 0.6, rows * 0.6]
    vertices = np.array([[bottom_left, top_left, top_right, bottom_right]], dtype=np.int32)
    # filling the polygon with white color and generating the final mask
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    # performing Bitwise AND on the input image and mask to get only the edges on the road
    masked_image = cv2.bitwise_and(image, mask)
    return masked_image

def hough_transform(image):
    """
    Determine and cut the region of interest in the input image.
    Parameter:
        image: grayscale image which should be an output from the edge detector
    """
    # Distance resolution of the accumulator in pixels.
    rho = 1
    # Angle resolution of the accumulator in radians.
    theta = np.pi/180
    # Only lines that are greater than threshold will be returned.
    threshold = 20
    # Line segments shorter than that are rejected.
    minLineLength = 20
    # Maximum allowed gap between points on the same line to link them
    maxLineGap = 500
    # function returns an array containing dimensions of straight lines
    # appearing in the input image
    return cv2.HoughLinesP(image, rho = rho, theta = theta, threshold = threshold,
                           minLineLength = minLineLength, maxLineGap = maxLineGap)

def average_slope_intercept(lines):
    """
    Find the slope and intercept of the left and right lanes of each image.
    Parameters:
        lines: output from Hough Transform
    """
    left_lines    = [] #(slope, intercept)
    left_weights  = [] #(length,)
    right_lines   = [] #(slope, intercept)
    right_weights = [] #(length,)

    for line in lines:
        for x1, y1, x2, y2 in line:
            if x1 == x2:
                continue
            # calculating slope of a line
            slope = (y2 - y1) / (x2 - x1)
            # calculating intercept of a line
            intercept = y1 - (slope * x1)
            # calculating length of a line
            length = np.sqrt(((y2 - y1) ** 2) + ((x2 - x1) ** 2))
            # slope of left lane is negative and for right lane slope is positive
            if slope < 0:
                left_lines.append((slope, intercept))
                left_weights.append((length))
            else:
                right_lines.append((slope, intercept))
                right_weights.append((length))
    #
    left_lane  = np.dot(left_weights,  left_lines) / np.sum(left_weights)  if len(left_weights) > 0 else None
    right_lane = np.dot(right_weights, right_lines) / np.sum(right_weights) if len(right_weights) > 0 else None
    return left_lane, right_lane

def pixel_points(y1, y2, line):
    """
    Converts the slope and intercept of each line into pixel points.
        Parameters:
            y1: y-value of the line's starting point.
            y2: y-value of the line's end point.
            line: The slope and intercept of the line.
    """
    if line is None:
        return None
    slope, intercept = line
    x1 = int((y1 - intercept)/slope)
    x2 = int((y2 - intercept)/slope)
    y1 = int(y1)
    y2 = int(y2)
    return ((x1, y1), (x2, y2))

def lane_lines(image, lines):
    """
    Create full lenght lines from pixel points.
        Parameters:
            image: The input test image.
            lines: The output lines from Hough Transform.
    """
    left_lane, right_lane = average_slope_intercept(lines)
    y1 = image.shape[0]
    y2 = y1 * 0.6
    left_line  = pixel_points(y1, y2, left_lane)
    right_line = pixel_points(y1, y2, right_lane)
    return left_line, right_line


def draw_lane_lines(image, lines, color=[255, 0, 0], thickness=12):
    """
    Draw lines onto the input image.
        Parameters:
            image: The input test image (video frame in our case).
            lines: The output lines from Hough Transform.
            color (Default = red): Line color.
            thickness (Default = 12): Line thickness.
    """
    line_image = np.zeros_like(image)
    for line in lines:
        if line is not None:
            cv2.line(line_image, *line,  color, thickness)
    return cv2.addWeighted(image, 1.0, line_image, 1.0, 0.0)

def frame_processor(image):
    """
    Process the input frame to detect lane lines.
    Parameters:
        image: image of a road where one wants to detect lane lines
        (we will be passing frames of video to this function)
    """
    # convert the RGB image to Gray scale
    grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # applying gaussian Blur which removes noise from the image
    # and focuses on our region of interest
    # size of gaussian kernel
    kernel_size = 5
    # Applying gaussian blur to remove noise from the frames
    blur = cv2.GaussianBlur(grayscale, (kernel_size, kernel_size), 0)
    # first threshold for the hysteresis procedure
    low_t = 50
    # second threshold for the hysteresis procedure
    high_t = 150
    # applying canny edge detection and save edges in a variable
    edges = cv2.Canny(blur, low_t, high_t)
    # since we are getting too many edges from our image, we apply
    # a mask polygon to only focus on the road
    # Will explain Region selection in detail in further steps
    region = region_selection(edges)
    # Applying hough transform to get straight lines from our image
    # and find the lane lines
    # Will explain Hough Transform in detail in further steps
    hough = hough_transform(region)
    #lastly we draw the lines on our resulting frame and return it as output
    result = draw_lane_lines(image, lane_lines(image, hough))
    return result

# driver function
def process_video(test_video, output_video):
    """
    Read input video stream and produce a video file with detected lane lines.
    Parameters:
        test_video: location of input video file
        output_video: location where output video file is to be saved
    """
    # read the video file using VideoFileClip without audio
    input_video = editor.VideoFileClip(test_video, audio=False)
    # apply the function "frame_processor" to each frame of the video
    # will give more detail about "frame_processor" in further steps
    # "processed" stores the output video
    processed = input_video.fl_image(frame_processor)
    # save the output video stream to an mp4 file
    processed.write_videofile(output_video, audio=False)

# calling driver function
process_video('input.mp4','output.mp4')
# Out:
# Moviepy - Building video output.mp4.
# Moviepy - Writing video output.mp4
# t:   6%|▌         | 80/1295 [00:03<01:43, 11.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 79/1296, at time 1.58/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 80/1296, at time 1.60/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   6%|▋         | 82/1295 [00:03<01:34, 12.82it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 81/1296, at time 1.62/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 82/1296, at time 1.64/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   6%|▋         | 84/1295 [00:03<01:30, 13.36it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 83/1296, at time 1.66/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 84/1296, at time 1.68/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 86/1295 [00:04<01:29, 13.55it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 85/1296, at time 1.70/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 86/1296, at time 1.72/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 87/1296, at time 1.74/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 89/1295 [00:04<01:17, 15.62it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 88/1296, at time 1.76/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 89/1296, at time 1.78/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 91/1295 [00:04<01:13, 16.47it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 90/1296, at time 1.80/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 91/1296, at time 1.82/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 93/1295 [00:04<01:19, 15.13it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 92/1296, at time 1.84/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 93/1296, at time 1.86/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 95/1295 [00:04<01:23, 14.32it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 94/1296, at time 1.88/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 95/1296, at time 1.90/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   7%|▋         | 97/1295 [00:04<01:23, 14.34it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 96/1296, at time 1.92/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 97/1296, at time 1.94/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 99/1295 [00:04<01:16, 15.56it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 98/1296, at time 1.96/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 99/1296, at time 1.98/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 100/1296, at time 2.00/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 102/1295 [00:05<01:14, 15.97it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 101/1296, at time 2.02/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 102/1296, at time 2.04/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 104/1295 [00:05<01:22, 14.39it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 103/1296, at time 2.06/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 104/1296, at time 2.08/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 106/1295 [00:05<01:28, 13.45it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 105/1296, at time 2.10/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 106/1296, at time 2.12/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 108/1295 [00:05<01:32, 12.89it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 107/1296, at time 2.14/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 108/1296, at time 2.16/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   8%|▊         | 110/1295 [00:05<01:38, 12.03it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 109/1296, at time 2.18/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 110/1296, at time 2.20/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▊         | 112/1295 [00:05<01:28, 13.42it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 111/1296, at time 2.22/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 112/1296, at time 2.24/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▉         | 114/1295 [00:06<01:28, 13.31it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 113/1296, at time 2.26/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 114/1296, at time 2.28/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 115/1296, at time 2.30/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▉         | 117/1295 [00:06<01:12, 16.15it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 116/1296, at time 2.32/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 117/1296, at time 2.34/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▉         | 119/1295 [00:06<01:17, 15.26it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 118/1296, at time 2.36/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 119/1296, at time 2.38/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▉         | 121/1295 [00:06<01:13, 16.03it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 120/1296, at time 2.40/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 121/1296, at time 2.42/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:   9%|▉         | 123/1295 [00:06<01:20, 14.64it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 122/1296, at time 2.44/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 123/1296, at time 2.46/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 124/1296, at time 2.48/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  10%|▉         | 126/1295 [00:06<01:18, 14.87it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 125/1296, at time 2.50/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 126/1296, at time 2.52/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 127/1296, at time 2.54/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  10%|▉         | 129/1295 [00:06<01:06, 17.45it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 128/1296, at time 2.56/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 129/1296, at time 2.58/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  10%|█         | 131/1295 [00:07<01:13, 15.91it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 130/1296, at time 2.60/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 131/1296, at time 2.62/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 132/1296, at time 2.64/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  10%|█         | 134/1295 [00:07<01:12, 16.09it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 133/1296, at time 2.66/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 134/1296, at time 2.68/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 135/1296, at time 2.70/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█         | 137/1295 [00:07<01:03, 18.16it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 136/1296, at time 2.72/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 137/1296, at time 2.74/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█         | 139/1295 [00:07<01:24, 13.61it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 138/1296, at time 2.76/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 139/1296, at time 2.78/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█         | 141/1295 [00:07<01:23, 13.87it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 140/1296, at time 2.80/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 141/1296, at time 2.82/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█         | 143/1295 [00:08<01:42, 11.22it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 142/1296, at time 2.84/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 143/1296, at time 2.86/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█         | 145/1295 [00:08<01:35, 12.09it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 144/1296, at time 2.88/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 145/1296, at time 2.90/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  11%|█▏        | 147/1295 [00:08<01:45, 10.83it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 146/1296, at time 2.92/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 147/1296, at time 2.94/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 149/1295 [00:08<01:34, 12.09it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 148/1296, at time 2.96/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 149/1296, at time 2.98/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 151/1295 [00:08<01:58,  9.65it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 150/1296, at time 3.00/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 151/1296, at time 3.02/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 153/1295 [00:08<01:48, 10.56it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 152/1296, at time 3.04/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 153/1296, at time 3.06/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 155/1295 [00:09<02:04,  9.18it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 154/1296, at time 3.08/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 155/1296, at time 3.10/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 157/1295 [00:09<01:46, 10.64it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 156/1296, at time 3.12/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 157/1296, at time 3.14/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  12%|█▏        | 159/1295 [00:09<01:33, 12.19it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 158/1296, at time 3.16/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 159/1296, at time 3.18/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 160/1296, at time 3.20/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 162/1295 [00:09<01:14, 15.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 161/1296, at time 3.22/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 162/1296, at time 3.24/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 164/1295 [00:09<01:09, 16.17it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 163/1296, at time 3.26/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 164/1296, at time 3.28/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 165/1296, at time 3.30/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 167/1295 [00:09<01:04, 17.39it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 166/1296, at time 3.32/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 167/1296, at time 3.34/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 169/1295 [00:09<01:03, 17.67it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 168/1296, at time 3.36/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 169/1296, at time 3.38/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 171/1295 [00:10<01:03, 17.75it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 170/1296, at time 3.40/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 171/1296, at time 3.42/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 172/1296, at time 3.44/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  13%|█▎        | 174/1295 [00:10<01:01, 18.16it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 173/1296, at time 3.46/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 174/1296, at time 3.48/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  14%|█▎        | 176/1295 [00:10<01:00, 18.49it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 175/1296, at time 3.50/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 176/1296, at time 3.52/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 177/1296, at time 3.54/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  14%|█▍        | 179/1295 [00:10<00:53, 20.80it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 178/1296, at time 3.56/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 179/1296, at time 3.58/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 180/1296, at time 3.60/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  14%|█▍        | 182/1295 [00:10<00:55, 20.18it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 181/1296, at time 3.62/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 182/1296, at time 3.64/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 183/1296, at time 3.66/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  14%|█▍        | 185/1295 [00:10<00:54, 20.40it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 184/1296, at time 3.68/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 185/1296, at time 3.70/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 186/1296, at time 3.72/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  15%|█▍        | 188/1295 [00:10<00:51, 21.68it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 187/1296, at time 3.74/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 188/1296, at time 3.76/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 189/1296, at time 3.78/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  15%|█▍        | 191/1295 [00:11<00:48, 22.58it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 190/1296, at time 3.80/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 191/1296, at time 3.82/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 192/1296, at time 3.84/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  15%|█▍        | 194/1295 [00:11<00:50, 21.65it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 193/1296, at time 3.86/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 194/1296, at time 3.88/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 195/1296, at time 3.90/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  15%|█▌        | 197/1295 [00:11<00:49, 22.24it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 196/1296, at time 3.92/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 197/1296, at time 3.94/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 198/1296, at time 3.96/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  15%|█▌        | 200/1295 [00:11<00:45, 24.07it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 199/1296, at time 3.98/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 200/1296, at time 4.00/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 201/1296, at time 4.02/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  16%|█▌        | 203/1295 [00:11<00:42, 25.51it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 202/1296, at time 4.04/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 203/1296, at time 4.06/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 204/1296, at time 4.08/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  16%|█▌        | 206/1295 [00:11<00:45, 23.97it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 205/1296, at time 4.10/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 206/1296, at time 4.12/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 207/1296, at time 4.14/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  16%|█▌        | 209/1295 [00:11<00:44, 24.16it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 208/1296, at time 4.16/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 209/1296, at time 4.18/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 210/1296, at time 4.20/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  16%|█▋        | 212/1295 [00:11<00:43, 24.83it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 211/1296, at time 4.22/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 212/1296, at time 4.24/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 213/1296, at time 4.26/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 214/1296, at time 4.28/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  17%|█▋        | 216/1295 [00:11<00:38, 28.00it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 215/1296, at time 4.30/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 216/1296, at time 4.32/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 217/1296, at time 4.34/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  17%|█▋        | 219/1295 [00:12<00:40, 26.55it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 218/1296, at time 4.36/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# ...
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1250/1296, at time 25.00/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  97%|█████████▋| 1252/1295 [01:08<00:02, 18.06it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1251/1296, at time 25.02/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1252/1296, at time 25.04/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  97%|█████████▋| 1254/1295 [01:08<00:02, 17.33it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1253/1296, at time 25.06/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1254/1296, at time 25.08/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  97%|█████████▋| 1256/1295 [01:08<00:02, 17.60it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1255/1296, at time 25.10/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1256/1296, at time 25.12/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  97%|█████████▋| 1258/1295 [01:08<00:02, 16.72it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1257/1296, at time 25.14/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1258/1296, at time 25.16/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1259/1296, at time 25.18/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  97%|█████████▋| 1261/1295 [01:08<00:01, 17.48it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1260/1296, at time 25.20/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1261/1296, at time 25.22/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1263/1295 [01:09<00:01, 16.07it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1262/1296, at time 25.24/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1263/1296, at time 25.26/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1265/1295 [01:09<00:01, 16.80it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1264/1296, at time 25.28/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1265/1296, at time 25.30/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1267/1295 [01:09<00:01, 16.60it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1266/1296, at time 25.32/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1267/1296, at time 25.34/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1269/1295 [01:09<00:01, 17.12it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1268/1296, at time 25.36/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1269/1296, at time 25.38/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1271/1295 [01:09<00:01, 17.41it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1270/1296, at time 25.40/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1271/1296, at time 25.42/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1273/1295 [01:09<00:01, 16.86it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1272/1296, at time 25.44/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1273/1296, at time 25.46/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  98%|█████████▊| 1275/1295 [01:09<00:01, 17.32it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1274/1296, at time 25.48/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1275/1296, at time 25.50/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▊| 1277/1295 [01:09<00:01, 16.27it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1276/1296, at time 25.52/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1277/1296, at time 25.54/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 1279/1295 [01:09<00:00, 16.28it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1278/1296, at time 25.56/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1279/1296, at time 25.58/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 1281/1295 [01:10<00:00, 15.81it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1280/1296, at time 25.60/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1281/1296, at time 25.62/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 1283/1295 [01:10<00:00, 16.32it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1282/1296, at time 25.64/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1283/1296, at time 25.66/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 1285/1295 [01:10<00:00, 15.37it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1284/1296, at time 25.68/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1285/1296, at time 25.70/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1286/1296, at time 25.72/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t:  99%|█████████▉| 1288/1295 [01:10<00:00, 16.12it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1287/1296, at time 25.74/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1288/1296, at time 25.76/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 1290/1295 [01:10<00:00, 16.79it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1289/1296, at time 25.78/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1290/1296, at time 25.80/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 1292/1295 [01:10<00:00, 17.11it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1291/1296, at time 25.82/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1292/1296, at time 25.84/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# t: 100%|█████████▉| 1294/1295 [01:10<00:00, 17.06it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1293/1296, at time 25.86/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file input.mp4, 2764800 bytes wanted but 0 bytes read,at frame 1294/1296, at time 25.88/25.90 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready output.mp4
